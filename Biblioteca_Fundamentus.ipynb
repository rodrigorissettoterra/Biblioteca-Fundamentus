# %% [markdown]
# <a href="https://colab.research.google.com/github/rodrigorissettoterra/Biblioteca-Fundamentus/blob/main/Biblioteca_Fundamentus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Utilizando a Biblioteca Fundamentus

# %% [markdown]
# ##Instalando a biblioteca Fundamentus

# %%
# !pip install fundamentus
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ##Importando as bibliotecas necessárias

# %%
#Importar as bibliotecas necessárias
import fundamentus
import pandas as pd

# %% [markdown]
# ##Criando o Dataframe com a biblioteca Fundamentus

# %%
df = fundamentus.get_resultado()

# %% [markdown]
# ##Visualizando o dataframe criado

# %% [markdown]
# ###Todo o dataframe

# %%
df
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AALR3        21.31  -18.61  2.35  2.308  0.0000  0.958 -30.73  83.88  -2.47
# ABCB3         0.00    0.00  0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# ABCB4        19.72    5.84  0.88  0.000  0.0649  0.000   0.00   0.00   0.00
# ABEV3        14.62   17.58  2.55  2.914  0.0521  1.621  35.01  14.97 -25.71
# ABYA3         4.91 -214.80  1.76  2.055  0.0000  0.527   1.98  19.96  -2.75
# ...            ...     ...   ...    ...     ...    ...    ...    ...    ...
# WLMM4        22.60    7.26  1.36  0.462  0.0457  1.114   2.65   7.08   3.25
# WMBY3        25.39  -19.30  2.87  0.836  0.0000  0.182   1.20   8.62  -1.50
# WSON33       67.00    8.07  0.98  1.067  0.0000  0.400  13.41   2.42  -0.89
# YDUQ3        10.05  -65.58  1.03  0.688  0.0126  0.313   2.09   5.70  -0.77
# ZAMP3         5.62  -20.87  1.06  0.441  0.0000  0.387  10.54  20.94  -1.01
#
# ...

# %% [markdown]
# ###Apenas as 5 primeiras linhas

# %%
df.head()
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AALR3        21.31  -18.61  2.35  2.308  0.0000  0.958 -30.73  83.88  -2.47
# ABCB3         0.00    0.00  0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# ABCB4        19.72    5.84  0.88  0.000  0.0649  0.000   0.00   0.00   0.00
# ABEV3        14.62   17.58  2.55  2.914  0.0521  1.621  35.01  14.97 -25.71
# ABYA3         4.91 -214.80  1.76  2.055  0.0000  0.527   1.98  19.96  -2.75
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# AALR3      105.92     21.75   0.0275 -0.1180  0.0132 -0.1263  0.86
# ABCB3        0.00      0.00   0.0000  0.0000  0.0000  0.1505  0.00
# ABCB4        0.00      0.00   0.0000  0.0000  0.0000  0.1505  0.00
# ABEV3       13.92     10.33   0.1947  0.1715  0.1498  0.1452  1.19
# ABYA3       33.67     33.67   0.1029 -0.0096  0.0278 -0.0082  2.09
#
# Multiples        liq2m       patrliq  divbpatr     c5y
# papel
# ...

# %% [markdown]
# ##Exportando o dataframe como um arquivo de Excel

# %%
df.to_excel("Fundamentus.xlsx")

# %% [markdown]
# ##Exportando o dataframe como um arquivo CSV

# %%
df.to_csv("Fundamentus.csv")
